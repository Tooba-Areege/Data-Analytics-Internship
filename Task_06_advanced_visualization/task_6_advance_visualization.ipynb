# %% [markdown]
# ### Step 1: Import Libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Step 2: Load cleaned dataset

# %%
df = pd.read_csv("cleaned_titanic.csv")

# %% [markdown]
# ###  Ste 3: Create data for stacked bar chart

# %%
stacked_data = pd.crosstab(df["Pclass"], df["Survived"])

# %% [markdown]
# ### Step 4: Stacked Bar Chart

# %%
plt.figure(figsize=(2,1))
stacked_data.plot(kind="bar", stacked=True)
plt.title("Survival by Passenger Class")
plt.xlabel("Passenger Class")
plt.ylabel("Number of Passengers")
plt.legend(["Did Not Survive", "Survived"])
plt.tight_layout()
plt.savefig("stacked_bar.png")
plt.show()

# %% [markdown]
# ### Step 5: Correlation Heatmap

# %%
correlation = df[["Age", "Fare", "SibSp", "Parch"]].corr()

# %%
plt.figure(figsize=(4,3))
plt.imshow(correlation, cmap="coolwarm")
plt.colorbar()
plt.xticks(range(len(correlation.columns)), correlation.columns)
plt.yticks(range(len(correlation.columns)), correlation.columns)
plt.title("Correlation Heatmap")
plt.tight_layout()
plt.savefig("heatmap.png")
plt.show()

# %%
print("Advanced charts created successfully!")
# Out:
# Advanced charts created successfully!
